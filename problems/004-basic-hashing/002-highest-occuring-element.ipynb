# %%
from collections import Counter
from collections import defaultdict


def max_frequency(lst: list[int]):
    if not lst:
        return None
    return Counter(lst).most_common(1)[0][0]


# def max_frequency(lst: list[int]):
#     freq = defaultdict(int)
#     for element in lst:
#         freq[element] += 1
#     max_freq = float("-inf")
#     max_key = None
#     for key, value in freq.items():
#         if value > max_freq:
#             max_freq = value
#             max_key = key
#     return max_key


# def max_frequency(lst: list[int]):
#     freq = {}
#     for element in lst:
#         freq[element] = freq.get(element, 0) + 1
#     max_freq = float("-inf")
#     max_key = None
#     for key, value in freq.items():
#         if value > max_freq:
#             max_freq = value
#             max_key = key
#     return max_key


print(max_frequency([10, 2, 4, 2, 1, 4, 10, 4, 5, 5, 3, 6]))
# Out:
# 4
